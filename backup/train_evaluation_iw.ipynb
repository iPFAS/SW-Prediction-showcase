# %%
import sys
import os
current_dir = os.getcwd()  
project_root = os.path.dirname(current_dir)  
sys.path.insert(0, project_root) 
from pathlib import Path
import warnings
import pandas as pd
from pycaret.regression import *
from src.config.config import Config
from src.data.data_loader import DataLoader
from src.models.model_evaluator import ModelEvaluator
from sklearn.feature_selection import SelectKBest, f_regression
from sklearn.ensemble import RandomForestRegressor

def train_models(train: pd.DataFrame,val: pd.DataFrame,target_column: str):
    """训练模型流程
    Args:
        data_path: 可选的数据文件路径
    """
    model_evaluator.setup_experiment(
        train_size=Config.MODEL_CONFIG['train_size'],
        train_data=train,
        val_data = val,
        target_column = target_column,
        categorical_features = Config.FEATURE_CONFIG['categorical_columns']
    )

    # 训练模型并返回最佳模型字典
    return model_evaluator.train_top_models(n_models=Config.MODEL_CONFIG['n_top_models'])

def tune(models: dict):
    """模型调优和集成"""
    # 对top模型进行调优
    tuned_models = model_evaluator.tune_models(models)

    return tuned_models

def ensemble(models: dict):
    """模型集成"""
    # 对top模型进行集成
    blended_model = model_evaluator.ensemble_models(models)

    return blended_model    
    # 模型
    
def save_models(models: dict):

    model_evaluator.saved_models(models)

def select_features(train_data: pd.DataFrame, test_data: pd.DataFrame, 
                   time_test_data: pd.DataFrame, n_features: int = 5) -> tuple:
    """选择最重要的特征
    
    Args:
        train_data: 训练数据
        test_data: 测试数据
        time_test_data: 时间测试数据
        n_features: 要选择的特征数量
        
    Returns:
        tuple: (处理后的训练集, 测试集, 时间测试集)
    """
    # 排除不需要的列
    feature_cols = [col for col in train_data.columns 
                    if col not in [Config.DATA_CONFIG['target_column'], 
                                 'Country Name', 'Year', 'Region', 'Income Group']]
    
    # 准备数据
    X = train_data[feature_cols]
    y = train_data[f"{Config.DATA_CONFIG['target_column']}_{Config.FEATURE_CONFIG['target_transform_method']}"]
    
    # 使用F-regression进行特征选择
    selector = SelectKBest(score_func=f_regression, k=n_features)
    selector.fit(X, y)
    
    # 获取选中的特征，排除目标变量
    target_transformed = f"{Config.DATA_CONFIG['target_column']}_{Config.FEATURE_CONFIG['target_transform_method']}"
    selected_features = pd.DataFrame({
        'feature': feature_cols,
        'score': selector.scores_
    }).sort_values('score', ascending=False).head(n_features)['feature'].tolist()
    
    print(f"\n选择的{n_features}个特征:")
    for i, feature in enumerate(selected_features, 1):
        print(f"{i}. {feature}")
    
    # 更新数据集，保留目标变量和转换后的目标变量
    selected_columns = selected_features + [target_transformed]
    train = train_data[selected_columns]
    test = test_data[selected_columns]
    time_test = time_test_data[selected_columns]
    
    return train, test, time_test

# %%
# 示例用法
df = pd.read_csv(Path(Config.PATH_CONFIG['features_dir'])  / 'training_data.csv')
data_loader = DataLoader()
model_evaluator = ModelEvaluator()

# 划分数据集
train_data, val_data, country_test_data = data_loader.split_data_by_countries(
    df,
    train_size=Config.DATA_CONFIG['country_train_size'],
    val_size=Config.DATA_CONFIG['country_val_size'],
    random_state=Config.DATA_CONFIG['random_state']
)

train_data, time_test_data = data_loader.split_data_by_time(train_data,
    test_size=Config.DATA_CONFIG['time_test_size'])

# 数据分析
print('\n训练集统计信息:')
data_loader.analyze_datasets(train_data)
print('\n验证集统计信息:')
data_loader.analyze_datasets(val_data)
print('\n外部国家测试集统计信息:')
data_loader.analyze_datasets(country_test_data)
print('\n外部时间测试集统计信息:')
data_loader.analyze_datasets(time_test_data)
#合并验证集和外部国家测试集作为测试集
test_data = pd.concat([val_data, country_test_data])
print('\n合并，作为测试集统计信息:')
data_loader.analyze_datasets(test_data)
# Out:
# 训练集统计信息:
# 总数据条数: 270
# 国家总数: 32
# 包含的国家: Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 53
# 特征列表: IW, IW_log, development_population_impact, economic_density, gdp_population_interaction, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, growth_synergy, industry_gdp_interaction, industry_population_interaction, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1990.0:1 | 1991.0:1 | 1992.0:1 | 1993.0:1 | 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:2 | 1998.0:2 | 1999.0:2 | 2000.0:2 | 2001.0:2 | 2002.0:2 | 2003.0:2 | 2004.0:26 | 2005.0:2 | 2006.0:26 | 2007.0:2 | 2008.0:29 | 2009.0:2 | 2010.0:31 | 2011.0:2 | 2012.0:31 | 2013.0:2 | 2014.0:30 | 2015.0:1 | 2016.0:30 | 2018.0:28 | 2020.0:7
#
# 验证集统计信息:
# 总数据条数: 48
# 国家总数: 3
# 包含的国家: Finland, Japan, Slovenia
#
# 特征数量: 53
# 特征列表: IW, IW_log, development_population_impact, economic_density, gdp_population_interaction, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, growth_synergy, industry_gdp_interaction, industry_population_interaction, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:1 | 1998.0:1 | 1999.0:1 | 2000.0:1 | 2001.0:1 | 2002.0:1 | 2003.0:1 | 2004.0:3 | 2005.0:1 | 2006.0:3 | 2007.0:1 | 2008.0:3 | 2009.0:1 | 2010.0:3 | 2011.0:1 | 2012.0:3 | 2013.0:1 | 2014.0:3 | 2015.0:1 | 2016.0:3 | 2017.0:1 | 2018.0:3 | 2019.0:1 | 2020.0:3 | 2021.0:1 | 2022.0:2
#
# 外部国家测试集统计信息:
# 总数据条数: 26
# 国家总数: 3
# 包含的国家: Bosnia and Herzegovina, Czechia, Germany
#
# 特征数量: 53
# 特征列表: IW, IW_log, development_population_impact, economic_density, gdp_population_interaction, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, growth_synergy, industry_gdp_interaction, industry_population_interaction, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2004.0:2 | 2006.0:2 | 2008.0:2 | 2010.0:2 | 2012.0:3 | 2014.0:3 | 2016.0:3 | 2018.0:3 | 2020.0:3 | 2022.0:3
#
# 外部时间测试集统计信息:
# 总数据条数: 60
# 国家总数: 33
# 包含的国家: Albania, Austria, Belgium, Bulgaria, China, Croatia, Cyprus, Denmark, Estonia, France, Greece, Hungary, Iceland, Ireland, Italy, Latvia, Lithuania, Luxembourg, Malta, Montenegro, Netherlands, North Macedonia, Norway, Poland, Portugal, Romania, Serbia, Slovak Republic, Spain, Sweden, Turkiye, United Kingdom, United States
#
# 特征数量: 53
# 特征列表: IW, IW_log, development_population_impact, economic_density, gdp_population_interaction, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, growth_synergy, industry_gdp_interaction, industry_population_interaction, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 2015.0:1 | 2016.0:1 | 2017.0:2 | 2018.0:4 | 2019.0:1 | 2020.0:22 | 2021.0:1 | 2022.0:28
#
# 合并，作为测试集统计信息:
# 总数据条数: 74
# 国家总数: 6
# 包含的国家: Bosnia and Herzegovina, Czechia, Finland, Germany, Japan, Slovenia
#
# 特征数量: 53
# 特征列表: IW, IW_log, development_population_impact, economic_density, gdp_population_interaction, gdp_ppp_2017_cubic, gdp_ppp_2017_growth, gdp_ppp_2017_log, gdp_ppp_2017_ma_3, gdp_ppp_2017_ma_5, gdp_ppp_2017_ma_7, gdp_ppp_2017_rel_change_3, gdp_ppp_2017_rel_change_5, gdp_ppp_2017_rel_change_7, gdp_ppp_2017_squared, gdp_ppp_2017_trend, gdp_ppp_2017_trend_deviation, gdp_ppp_2017_trend_strength_3, gdp_ppp_2017_trend_strength_5, gdp_ppp_2017_trend_strength_7, gdp_ppp_per_capita_2017_cubic, gdp_ppp_per_capita_2017_growth, gdp_ppp_per_capita_2017_log, gdp_ppp_per_capita_2017_ma_3, gdp_ppp_per_capita_2017_ma_5, gdp_ppp_per_capita_2017_ma_7, gdp_ppp_per_capita_2017_rel_change_3, gdp_ppp_per_capita_2017_rel_change_5, gdp_ppp_per_capita_2017_rel_change_7, gdp_ppp_per_capita_2017_squared, gdp_ppp_per_capita_2017_trend, gdp_ppp_per_capita_2017_trend_deviation, gdp_ppp_per_capita_2017_trend_strength_3, gdp_ppp_per_capita_2017_trend_strength_5, gdp_ppp_per_capita_2017_trend_strength_7, growth_synergy, industry_gdp_interaction, industry_population_interaction, population_cubic, population_growth, population_log, population_ma_3, population_ma_5, population_ma_7, population_rel_change_3, population_rel_change_5, population_rel_change_7, population_squared, population_trend, population_trend_deviation, population_trend_strength_3, population_trend_strength_5, population_trend_strength_7
#
# 年份分布: 1994.0:1 | 1995.0:1 | 1996.0:1 | 1997.0:1 | 1998.0:1 | 1999.0:1 | 2000.0:1 | 2001.0:1 | 2002.0:1 | 2003.0:1 | 2004.0:5 | 2005.0:1 | 2006.0:5 | 2007.0:1 | 2008.0:5 | 2009.0:1 | 2010.0:5 | 2011.0:1 | 2012.0:6 | 2013.0:1 | 2014.0:6 | 2015.0:1 | 2016.0:6 | 2017.0:1 | 2018.0:6 | 2019.0:1 | 2020.0:6 | 2021.0:1 | 2022.0:5

# %%
train_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'train.csv'), index=False)
test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'test.csv'), index=False)
time_test_data.to_csv(os.path.join(Config.PATH_CONFIG['data_dir'], 'time_test_data.csv'), index=False)

# 排除不需要的列
feature_cols = [col for col in train_data.columns 
                if col not in [Config.DATA_CONFIG['target_column'], 'Country Name', 'Year','Region', 'Income Group']]

train = train_data[feature_cols]
test = test_data[feature_cols]
time_test_data = time_test_data[feature_cols] 

target_column = Config.DATA_CONFIG['target_column']
method = Config.FEATURE_CONFIG['target_transform_method']
transformed_column = f'{target_column}_{method}'

# 使用方法
train, test, time_test_data = select_features(train_data, test_data, time_test_data,n_features=15 )
# Out:
# 选择的15个特征:
# 1. IW_log
# 2. population_log
# 3. population_squared
# 4. population_cubic
# 5. economic_density
# 6. gdp_ppp_2017_log
# 7. gdp_ppp_2017_squared
# 8. gdp_ppp_2017_cubic
# 9. industry_population_interaction
# 10. gdp_population_interaction
# 11. industry_gdp_interaction
# 12. population_trend
# 13. population_ma_7
# 14. population_ma_5
# 15. population_ma_3

# %%
# 训练模型
models = train_models(train,test,transformed_column)
# Out:
# <style type="text/css">
# #T_fca96_row8_col1, #T_fca96_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_fca96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fca96_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_fca96_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fca96_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fca96_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_fca96_row0_col1" class="data row0 col1" >888</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fca96_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_fca96_row1_col1" class="data row1 col1" >IW_log</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fca96_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_fca96_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fca96_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_fca96_row3_col1" class="data row3 col1" >(344, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fca96_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_fca96_row4_col1" class="data row4 col1" >(344, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fca96_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_fca96_row5_col1" class="data row5 col1" >(270, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fca96_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_fca96_row6_col1" class="data row6 col1" >(74, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fca96_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_fca96_row7_col1" class="data row7 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fca96_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_fca96_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fca96_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_fca96_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fca96_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_fca96_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fca96_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_fca96_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fca96_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_fca96_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fca96_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_fca96_row13_col1" class="data row13 col1" >minmax</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fca96_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_fca96_row14_col1" class="data row14 col1" >TimeSeriesSplit</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fca96_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_fca96_row15_col1" class="data row15 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fca96_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_fca96_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fca96_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_fca96_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fca96_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_fca96_row18_col1" class="data row18 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fca96_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_fca96_row19_col1" class="data row19 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_fca96_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_fca96_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_fca96_row20_col1" class="data row20 col1" >db65</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_c6fdc th {
#   text-align: left;
# }
# #T_c6fdc_row0_col0, #T_c6fdc_row0_col4, #T_c6fdc_row1_col0, #T_c6fdc_row1_col1, #T_c6fdc_row1_col2, #T_c6fdc_row1_col3, #T_c6fdc_row1_col5, #T_c6fdc_row1_col6, #T_c6fdc_row2_col0, #T_c6fdc_row2_col1, #T_c6fdc_row2_col2, #T_c6fdc_row2_col3, #T_c6fdc_row2_col4, #T_c6fdc_row2_col5, #T_c6fdc_row2_col6, #T_c6fdc_row3_col0, #T_c6fdc_row3_col1, #T_c6fdc_row3_col2, #T_c6fdc_row3_col3, #T_c6fdc_row3_col4, #T_c6fdc_row3_col5, #T_c6fdc_row3_col6, #T_c6fdc_row4_col0, #T_c6fdc_row4_col1, #T_c6fdc_row4_col2, #T_c6fdc_row4_col3, #T_c6fdc_row4_col4, #T_c6fdc_row4_col5, #T_c6fdc_row4_col6, #T_c6fdc_row5_col0, #T_c6fdc_row5_col1, #T_c6fdc_row5_col2, #T_c6fdc_row5_col3, #T_c6fdc_row5_col4, #T_c6fdc_row5_col5, #T_c6fdc_row5_col6, #T_c6fdc_row6_col0, #T_c6fdc_row6_col1, #T_c6fdc_row6_col2, #T_c6fdc_row6_col3, #T_c6fdc_row6_col4, #T_c6fdc_row6_col5, #T_c6fdc_row6_col6, #T_c6fdc_row7_col0, #T_c6fdc_row7_col1, #T_c6fdc_row7_col2, #T_c6fdc_row7_col3, #T_c6fdc_row7_col4, #T_c6fdc_row7_col5, #T_c6fdc_row7_col6, #T_c6fdc_row8_col0, #T_c6fdc_row8_col1, #T_c6fdc_row8_col2, #T_c6fdc_row8_col3, #T_c6fdc_row8_col4, #T_c6fdc_row8_col5, #T_c6fdc_row8_col6, #T_c6fdc_row9_col0, #T_c6fdc_row9_col1, #T_c6fdc_row9_col2, #T_c6fdc_row9_col3, #T_c6fdc_row9_col4, #T_c6fdc_row9_col5, #T_c6fdc_row9_col6, #T_c6fdc_row10_col0, #T_c6fdc_row10_col1, #T_c6fdc_row10_col2, #T_c6fdc_row10_col3, #T_c6fdc_row10_col4, #T_c6fdc_row10_col5, #T_c6fdc_row10_col6, #T_c6fdc_row11_col0, #T_c6fdc_row11_col1, #T_c6fdc_row11_col2, #T_c6fdc_row11_col3, #T_c6fdc_row11_col4, #T_c6fdc_row11_col5, #T_c6fdc_row11_col6, #T_c6fdc_row12_col0, #T_c6fdc_row12_col1, #T_c6fdc_row12_col2, #T_c6fdc_row12_col3, #T_c6fdc_row12_col4, #T_c6fdc_row12_col5, #T_c6fdc_row12_col6, #T_c6fdc_row13_col0, #T_c6fdc_row13_col1, #T_c6fdc_row13_col2, #T_c6fdc_row13_col3, #T_c6fdc_row13_col4, #T_c6fdc_row13_col5, #T_c6fdc_row13_col6, #T_c6fdc_row14_col0, #T_c6fdc_row14_col1, #T_c6fdc_row14_col2, #T_c6fdc_row14_col3, #T_c6fdc_row14_col4, #T_c6fdc_row14_col5, #T_c6fdc_row14_col6, #T_c6fdc_row15_col0, #T_c6fdc_row15_col1, #T_c6fdc_row15_col2, #T_c6fdc_row15_col3, #T_c6fdc_row15_col4, #T_c6fdc_row15_col5, #T_c6fdc_row15_col6, #T_c6fdc_row16_col0, #T_c6fdc_row16_col1, #T_c6fdc_row16_col2, #T_c6fdc_row16_col3, #T_c6fdc_row16_col4, #T_c6fdc_row16_col5, #T_c6fdc_row16_col6, #T_c6fdc_row17_col0, #T_c6fdc_row17_col1, #T_c6fdc_row17_col2, #T_c6fdc_row17_col3, #T_c6fdc_row17_col4, #T_c6fdc_row17_col5, #T_c6fdc_row17_col6, #T_c6fdc_row18_col0, #T_c6fdc_row18_col1, #T_c6fdc_row18_col2, #T_c6fdc_row18_col3, #T_c6fdc_row18_col4, #T_c6fdc_row18_col5, #T_c6fdc_row18_col6, #T_c6fdc_row19_col0, #T_c6fdc_row19_col1, #T_c6fdc_row19_col2, #T_c6fdc_row19_col3, #T_c6fdc_row19_col4, #T_c6fdc_row19_col5, #T_c6fdc_row19_col6 {
#   text-align: left;
# }
# #T_c6fdc_row0_col1, #T_c6fdc_row0_col2, #T_c6fdc_row0_col3, #T_c6fdc_row0_col5, #T_c6fdc_row0_col6, #T_c6fdc_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c6fdc_row0_col7, #T_c6fdc_row1_col7, #T_c6fdc_row2_col7, #T_c6fdc_row3_col7, #T_c6fdc_row4_col7, #T_c6fdc_row5_col7, #T_c6fdc_row6_col7, #T_c6fdc_row7_col7, #T_c6fdc_row8_col7, #T_c6fdc_row9_col7, #T_c6fdc_row10_col7, #T_c6fdc_row11_col7, #T_c6fdc_row12_col7, #T_c6fdc_row13_col7, #T_c6fdc_row14_col7, #T_c6fdc_row15_col7, #T_c6fdc_row16_col7, #T_c6fdc_row18_col7, #T_c6fdc_row19_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c6fdc_row17_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c6fdc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6fdc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_c6fdc_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_c6fdc_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_c6fdc_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_c6fdc_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_c6fdc_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_c6fdc_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_c6fdc_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6fdc_level0_row0" class="row_heading level0 row0" >omp</th>
#       <td id="T_c6fdc_row0_col0" class="data row0 col0" >Orthogonal Matching Pursuit</td>
#       <td id="T_c6fdc_row0_col1" class="data row0 col1" >0.9300</td>
#       <td id="T_c6fdc_row0_col2" class="data row0 col2" >1.2835</td>
#       <td id="T_c6fdc_row0_col3" class="data row0 col3" >1.1233</td>
#       <td id="T_c6fdc_row0_col4" class="data row0 col4" >0.3691</td>
#       <td id="T_c6fdc_row0_col5" class="data row0 col5" >0.0619</td>
#       <td id="T_c6fdc_row0_col6" class="data row0 col6" >0.0540</td>
#       <td id="T_c6fdc_row0_col7" class="data row0 col7" >0.3360</td>
#     </tr>
#     <tr>
#       <th id="T_c6fdc_level0_row1" class="row_heading level0 row1" >catboost</th>
#       <td id="T_c6fdc_row1_col0" class="data row1 col0" >CatBoost Regressor</td>
#       <td id="T_c6fdc_row1_col1" class="data row1 col1" >1.0155</td>
#       <td id="T_c6fdc_row1_col2" class="data row1 col2" >1.7936</td>
#       <td id="T_c6fdc_row1_col3" class="data row1 col3" >1.2306</td>
#       <td id="T_c6fdc_row1_col4" class="data row1 col4" >0.3921</td>
#       <td id="T_c6fdc_row1_col5" class="data row1 col5" >0.0664</td>
#       <td id="T_c6fdc_row1_col6" class="data row1 col6" >0.0570</td>
#       <td id="T_c6fdc_row1_col7" class="data row1 col7" >0.3240</td>
#     </tr>
#     <tr>
#       <th id="T_c6fdc_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_c6fdc_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c6fdc_row2_col1" class="data row2 col1" >0.9984</td>
#       <td id="T_c6fdc_row2_col2" class="data row2 col2" >1.8427</td>
#       <td id="T_c6fdc_row2_col3" class="data row2 col3" >1.2637</td>
#       <td id="T_c6fdc_row2_col4" class="data row2 col4" >0.1819</td>
#       <td id="T_c6fdc_row2_col5" class="data row2 col5" >0.0703</td>
#       <td id="T_c6fdc_row2_col6" class="data row2 col6" >0.0572</td>
#       <td id="T_c6fdc_row2_col7" class="data row2 col7" >0.0340</td>
#     </tr>
#     <tr>
#       <th id="T_c6fdc_level0_row3" class="row_heading level0 row3" >et</th>
#       <td id="T_c6fdc_row3_col0" class="data row3 col0" >Extra Trees Regressor</td>
#       <td id="T_c6fdc_row3_col1" class="data row3 col1" >1.0596</td>
#       <td id="T_c6fdc_row3_col2" class="data row3 col2" >1.8973</td>
#       <td id="T_c6fdc_row3_col3" class="data row3 col3" >1.2960</td>
#       <td id="T_c6fdc_row3_col4" class="data row3 col4" >0.2768</td>
#       <td id="T_c6fdc_row3_col5" class="data row3 col5" >0.0709</td>
#       <td id="T_c6fdc_row3_col6" class="data row3 col6" >0.0600</td>
#       <td id="T_c6fdc_row3_col7" class="data row3 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_c6fdc_level0_row4" class="row_heading level0 row4" >rf</th>
#       <td id="T_c6fdc_row4_col0" class="data row4 col0" >Random Forest Regressor</td>
#       <td id="T_c6fdc_row4_col1" class="data row4 col1" >1.0553</td>
#       <td id="T_c6fdc_row4_col2" class="data row4 col2" >1.9815</td>
#       <td id="T_c6fdc_row4_col3" class="data row4 col3" >1.2979</td>
#       <td id="T_c6fdc_row4_col4" class="data row4 col4" >0.3115</td>
#       <td id="T_c6fdc_row4_col5" class="data row4 col5" >0.0706</td>
#       <td id="T_c6fdc_row4_col6" class="data row4 col6" >0.0594</td>
#       <td id="T_c6fdc_row4_col7" class="data row4 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_c6fdc_level0_row5" class="row_heading level0 row5" >xgboost</th>
#       <td id="T_c6fdc_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_c6fdc_row5_col1" class="data row5 col1" >1.0455</td>
#       <td id="T_c6fdc_row5_col2" class="data row5 col2" >2.0605</td>
#       <td id="T_c6fdc_row5_col3" class="data r

# %%
# 定义需要包含的模型简称集合
include_models = {'rf','xgboost','et','lightgbm','gbr','catboost'}

# 生成过滤后的有序字典
model_dict = {
    k: v for k, v in models.items()
    if k in include_models
}

# %%
print(f'当前调优模型: {", ".join(model_dict.keys())}')

# 调优
tune_models = tune(model_dict)
# Out:
# 当前调优模型: catboost, lightgbm, et, rf, xgboost, gbr
# 当前调优模型: catboost , 结果如下:
# <style type="text/css">
# #T_7a25b_row5_col0, #T_7a25b_row5_col1, #T_7a25b_row5_col2, #T_7a25b_row5_col3, #T_7a25b_row5_col4, #T_7a25b_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_7a25b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a25b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7a25b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7a25b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7a25b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7a25b_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_7a25b_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a25b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a25b_row0_col0" class="data row0 col0" >0.9234</td>
#       <td id="T_7a25b_row0_col1" class="data row0 col1" >1.0518</td>
#       <td id="T_7a25b_row0_col2" class="data row0 col2" >1.0256</td>
#       <td id="T_7a25b_row0_col3" class="data row0 col3" >0.5117</td>
#       <td id="T_7a25b_row0_col4" class="data row0 col4" >0.0563</td>
#       <td id="T_7a25b_row0_col5" class="data row0 col5" >0.0546</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7a25b_row1_col0" class="data row1 col0" >0.8117</td>
#       <td id="T_7a25b_row1_col1" class="data row1 col1" >1.0927</td>
#       <td id="T_7a25b_row1_col2" class="data row1 col2" >1.0453</td>
#       <td id="T_7a25b_row1_col3" class="data row1 col3" >-0.1345</td>
#       <td id="T_7a25b_row1_col4" class="data row1 col4" >0.0598</td>
#       <td id="T_7a25b_row1_col5" class="data row1 col5" >0.0476</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7a25b_row2_col0" class="data row2 col0" >0.6583</td>
#       <td id="T_7a25b_row2_col1" class="data row2 col1" >0.7517</td>
#       <td id="T_7a25b_row2_col2" class="data row2 col2" >0.8670</td>
#       <td id="T_7a25b_row2_col3" class="data row2 col3" >0.8102</td>
#       <td id="T_7a25b_row2_col4" class="data row2 col4" >0.0483</td>
#       <td id="T_7a25b_row2_col5" class="data row2 col5" >0.0400</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7a25b_row3_col0" class="data row3 col0" >0.4768</td>
#       <td id="T_7a25b_row3_col1" class="data row3 col1" >0.3366</td>
#       <td id="T_7a25b_row3_col2" class="data row3 col2" >0.5802</td>
#       <td id="T_7a25b_row3_col3" class="data row3 col3" >0.9020</td>
#       <td id="T_7a25b_row3_col4" class="data row3 col4" >0.0338</td>
#       <td id="T_7a25b_row3_col5" class="data row3 col5" >0.0288</td>
#     </tr>
#     <tr>
#       <th id="T_7a25b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7
_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_efd3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efd3c_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_efd3c_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_efd3c_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_efd3c_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_efd3c_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_efd3c_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efd3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_efd3c_row0_col0" class="data row0 col0" >1.1975</td>
#       <td id="T_efd3c_row0_col1" class="data row0 col1" >1.8092</td>
#       <td id="T_efd3c_row0_col2" class="data row0 col2" >1.3451</td>
#       <td id="T_efd3c_row0_col3" class="data row0 col3" >0.1602</td>
#       <td id="T_efd3c_row0_col4" class="data row0 col4" >0.0744</td>
#       <td id="T_efd3c_row0_col5" class="data row0 col5" >0.0703</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_efd3c_row1_col0" class="data row1 col0" >0.8863</td>
#       <td id="T_efd3c_row1_col1" class="data row1 col1" >1.6249</td>
#       <td id="T_efd3c_row1_col2" class="data row1 col2" >1.2747</td>
#       <td id="T_efd3c_row1_col3" class="data row1 col3" >-0.6871</td>
#       <td id="T_efd3c_row1_col4" class="data row1 col4" >0.0741</td>
#       <td id="T_efd3c_row1_col5" class="data row1 col5" >0.0521</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_efd3c_row2_col0" class="data row2 col0" >0.5550</td>
#       <td id="T_efd3c_row2_col1" class="data row2 col1" >0.4516</td>
#       <td id="T_efd3c_row2_col2" class="data row2 col2" >0.6720</td>
#       <td id="T_efd3c_row2_col3" class="data row2 col3" >0.8860</td>
#       <td id="T_efd3c_row2_col4" class="data row2 col4" >0.0379</td>
#       <td id="T_efd3c_row2_col5" class="data row2 col5" >0.0338</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_efd3c_row3_col0" class="data row3 col0" >0.6921</td>
#       <td id="T_efd3c_row3_col1" class="data row3 col1" >0.8723</td>
#       <td id="T_efd3c_row3_col2" class="data row3 col2" >0.9339</td>
#       <td id="T_efd3c_row3_col3" class="data row3 col3" >0.7461</td>
#       <td id="T_efd3c_row3_col4" class="data row3 col4" >0.0557</td>
#       <td id="T_efd3c_row3_col5" class="data row3 col5" >0.0427</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_efd3c_row4_col0" class="data row4 col0" >1.7588</td>
#       <td id="T_efd3c_row4_col1" class="data row4 col1" >4.0729</td>
#       <td id="T_efd3c_row4_col2" class="data row4 col2" >2.0181</td>
#       <td id="T_efd3c_row4_col3" class="data row4 col3" >0.4768</td>
#       <td id="T_efd3c_row4_col4" class="data row4 col4" >0.0989</td>
#       <td id="T_efd3c_row4_col5" class="data row4 col5" >0.0888</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_efd3c_row5_col0" class="data row5 col0" >1.0179</td>
#       <td id="T_efd3c_row5_col1" class="data row5 col1" >1.7662</td>
#       <td id="T_efd3c_row5_col2" class="data row5 col2" >1.2488</td>
#       <td id="T_efd3c_row5_col3" class="data row5 col3" >0.3164</td>
#       <td id="T_efd3c_row5_col4" class="data row5 col4" >0.0682</td>
#       <td id="T_efd3c_row5_col5" class="data row5 col5" >0.0575</td>
#     </tr>
#     <tr>
#       <th id="T_efd3c_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_efd3c_row6_col0" class="data row6 col0" >0.4287</td>
#       <td id="T_efd3c_row6_col1" class="data row6 col1" >1.2546</td>
#       <td id="T_efd3c_row6_col2" class="data row6 col2" >0.4547</td>
#       <td id="T_efd3c_row6_col3" class="data row6 col3" >0.5597</td>
#       <td id="T_efd3c_row6_col4" class="data row6 col4" >0.0204</td>
#       <td id="T_efd3c_row6_col5" class="data row6 col5" >0.0198</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_
col5" >0.0890</td>
#     </tr>
#     <tr>
#       <th id="T_89c2a_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_89c2a_row5_col0" class="data row5 col0" >0.9746</td>
#       <td id="T_89c2a_row5_col1" class="data row5 col1" >1.6202</td>
#       <td id="T_89c2a_row5_col2" class="data row5 col2" >1.1995</td>
#       <td id="T_89c2a_row5_col3" class="data row5 col3" >0.3871</td>
#       <td id="T_89c2a_row5_col4" class="data row5 col4" >0.0655</td>
#       <td id="T_89c2a_row5_col5" class="data row5 col5" >0.0557</td>
#     </tr>
#     <tr>
#       <th id="T_89c2a_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_89c2a_row6_col0" class="data row6 col0" >0.4152</td>
#       <td id="T_89c2a_row6_col1" class="data row6 col1" >1.1952</td>
#       <td id="T_89c2a_row6_col2" class="data row6 col2" >0.4260</td>
#       <td id="T_89c2a_row6_col3" class="data row6 col3" >0.5163</td>
#       <td id="T_89c2a_row6_col4" class="data row6 col4" >0.0185</td>
#       <td id="T_89c2a_row6_col5" class="data row6 col5" >0.0190</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_324b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_324b1_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_324b1_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_324b1_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_324b1_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_324b1_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_324b1_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_324b1_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_324b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_324b1_row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#       <td id="T_324b1_row0_col1" class="data row0 col1" >0.7906</td>
#       <td id="T_324b1_row0_col2" class="data row0 col2" >1.0141</td>
#       <td id="T_324b1_row0_col3" class="data row0 col3" >1.0070</td>
#       <td id="T_324b1_row0_col4" class="data row0 col4" >0.5361</td>
#       <td id="T_324b1_row0_col5" class="data row0 col5" >0.0547</td>
#       <td id="T_324b1_row0_col6" class="data row0 col6" >0.0437</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: xgboost , 结果如下:
# <style type="text/css">
# #T_4b570_row5_col0, #T_4b570_row5_col1, #T_4b570_row5_col2, #T_4b570_row5_col3, #T_4b570_row5_col4, #T_4b570_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_4b570">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4b570_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_4b570_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_4b570_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_4b570_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_4b570_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_4b570_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4b570_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4b570_row0_col0" class="data row0 col0" >1.0499</td>
#       <td id="T_4b570_row0_col1" class="data row0 col1" >1.3706</td>
#       <td id="T_4b570_row0_col2" class="data row0 col2" >1.1707</td>
#       <td id="T_4b570_row0_col3" class="data row0 col3" >0.3638</td>
#       <td id="T_4b570_row0_col4" class="data row0 col4" >0.0662</td>
#       <td id="T_4b570_row0_col5" class="data row0 col5" >0.0629</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4b570_row1_col0" class="data row1 col0" >0.9497</td>
#       <td id="T_4b570_row1_col1" class="data row1 col1" >1.7387</td>
#       <td id="T_4b570_row1_col2" class="data row1 col2" >1.3186</td>
#       <td id="T_4b570_row1_col3" class="data row1 col3" >-0.8053</td>
#       <td id="T_4b570_row1_col4" class="data row1 col4" >0.0767</td>
#       <td id="T_4b570_row1_col5" class="data row1 col5" >0.0559</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4b570_row2_col0" class="data row2 col0" >0.8471</td>
#       <td id="T_4b570_row2_col1" class="data row2 col1" >1.0074</td>
#       <td id="T_4b570_row2_col2" class="data row2 col2" >1.0037</td>
#       <td id="T_4b570_row2_col3" class="data row2 col3" >0.7457</td>
#       <td id="T_4b570_row2_col4" class="data row2 col4" >0.0579</td>
#       <td id="T_4b570_row2_col5" class="data row2 col5" >0.0528</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4b570_row3_col0" class="data row3 col0" >0.4502</td>
#       <td id="T_4b570_row3_col1" class="data row3 col1" >0.3524</td>
#       <td id="T_4b570_row3_col2" class="data row3 col2" >0.5936</td>
#       <td id="T_4b570_row3_col3" class="data row3 col3" >0.8974</td>
#       <td id="T_4b570_row3_col4" class="data row3 col4" >0.0359</td>
#       <td id="T_4b570_row3_col5" class="data row3 col5" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4b570_row4_col0" class="data row4 col0" >1.7358</td>
#       <td id="T_4b570_row4_col1" class="data row4 col1" >4.1046</td>
#       <td id="T_4b570_row4_col2" class="data row4 col2" >2.0260</td>
#       <td id="T_4b570_row4_col3" class="data row4 col3" >0.4727</td>
#       <td id="T_4b570_row4_col4" class="data row4 col4" >0.0989</td>
#       <td id="T_4b570_row4_col5" class="data row4 col5" >0.0870</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_4b570_row5_col0" class="data row5 col0" >1.0065</td>
#       <td id="T_4b570_row5_col1" class="data row5 col1" >1.7147</td>
#       <td id="T_4b570_row5_col2" class="data row5 col2" >1.2225</td>
#       <td id="T_4b570_row5_col3" class="data row5 col3" >0.3349</td>
#       <td id="T_4b570_row5_col4" class="data row5 col4" >0.0671</td>
#       <td id="T_4b570_row5_col5" class="data row5 col5" >0.0573</td>
#     </tr>
#     <tr>
#       <th id="T_4b570_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_4b570_row6_col0" class="data row6 col0" >0.4176</td>
#       <td id="T_4b570_row6_col1" class="data row6 col1" >1.2796</td>
#       <td id="T_4b570_row6_col2" class="data row6 col2" >0.4692</td>
#       <td id="T_4b570_row6_col3" class="data row6 col3" >0.6008</td>
#       <td id="T_4b570_row6_col4" class="data row6 col4" >0.0208</td>
#       <td id="T_4b570_row6_col5" class="data row6 col5" >0.0189</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_4abee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4abee_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4abee_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4abee_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4abee_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4abee_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4abee_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4abee_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4abee_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4abee_row0_col0" class="data row0 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4abee_row0_col1" class="data row0 col1" >0.7466</td>
#       <td id="T_4abee_row0_col2" class="data row0 col2" >0.8968</td>
#       <td id="T_4abee_row0_col3" class="data row0 col3" >0.9470</td>
#       <td id="T_4abee_row0_col4" class="data row0 col4" >0.5897</td>
#       <td id="T_4abee_row0_col5" class="data row0 col5" >0.0513</td>
#       <td id="T_4abee_row0_col6" class="data row0 col6" >0.0414</td>
#     </tr>
#   </tbody>
# </table>
# 当前调优模型: gbr , 结果如下:
# <style type="text/css">
# #T_d14ea_row5_col0, #T_d14ea_row5_col1, #T_d14ea_row5_col2, #T_d14ea_row5_col3, #T_d14ea_row5_col4, #T_d14ea_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d14ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d14ea_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d14ea_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d14ea_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d14ea_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d14ea_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d14ea_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d14ea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d14ea_row0_col0" class="data row0 col0" >1.0890</td>
#       <td id="T_d14ea_row0_col1" class="data row0 col1" >1.3911</td>
#       <td id="T_d14ea_row0_col2" class="data row0 col2" >1.1795</td>
#       <td id="T_d14ea_row0_col3" class="data row0 col3" >0.3542</td>
#       <td id="T_d14ea_row0_col4" class="data row0 col4" >0.0653</td>
#       <td id="T_d14ea_row0_col5" class="data row0 col5" >0.0646</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d14ea_row1_col0" class="data row1 col0" >0.8660</td>
#       <td id="T_d14ea_row1_col1" class="data row1 col1" >1.4913</td>
#       <td id="T_d14ea_row1_col2" class="data row1 col2" >1.2212</td>
#       <td id="T_d14ea_row1_col3" class="data row1 col3" >-0.5485</td>
#       <td id="T_d14ea_row1_col4" class="data row1 col4" >0.0707</td>
#       <td id="T_d14ea_row1_col5" class="data row1 col5" >0.0509</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d14ea_row2_col0" class="data row2 col0" >0.7370</td>
#       <td id="T_d14ea_row2_col1" class="data row2 col1" >0.8106</td>
#       <td id="T_d14ea_row2_col2" class="data row2 col2" >0.9003</td>
#       <td id="T_d14ea_row2_col3" class="data row2 col3" >0.7954</td>
#       <td id="T_d14ea_row2_col4" class="data row2 col4" >0.0498</td>
#       <td id="T_d14ea_row2_col5" class="data row2 col5" >0.0448</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d14ea_row3_col0" class="data row3 col0" >0.5792</td>
#       <td id="T_d14ea_row3_col1" class="data row3 col1" >0.6113</td>
#       <td id="T_d14ea_row3_col2" class="data row3 col2" >0.7819</td>
#       <td id="T_d14ea_row3_col3" class="data row3 col3" >0.8221</td>
#       <td id="T_d14ea_row3_col4" class="data row3 col4" >0.0474</td>
#       <td id="T_d14ea_row3_col5" class="data row3 col5" >0.0359</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d14ea_row4_col0" class="data row4 col0" >1.9186</td>
#       <td id="T_d14ea_row4_col1" class="data row4 col1" >4.9648</td>
#       <td id="T_d14ea_row4_col2" class="data row4 col2" >2.2282</td>
#       <td id="T_d14ea_row4_col3" class="data row4 col3" >0.3622</td>
#       <td id="T_d14ea_row4_col4" class="data row4 col4" >0.1091</td>
#       <td id="T_d14ea_row4_col5" class="data row4 col5" >0.0956</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row5" class="row_heading level0 row5" >Mean</th>
#       <td id="T_d14ea_row5_col0" class="data row5 col0" >1.0380</td>
#       <td id="T_d14ea_row5_col1" class="data row5 col1" >1.8538</td>
#       <td id="T_d14ea_row5_col2" class="data row5 col2" >1.2622</td>
#       <td id="T_d14ea_row5_col3" class="data row5 col3" >0.3571</td>
#       <td id="T_d14ea_row5_col4" class="data row5 col4" >0.0685</td>
#       <td id="T_d14ea_row5_col5" class="data row5 col5" >0.0584</td>
#     </tr>
#     <tr>
#       <th id="T_d14ea_level0_row6" class="row_heading level0 row6" >Std</th>
#       <td id="T_d14ea_row6_col0" class="data row6 col0" >0.4709</td>
#       <td id="T_d14ea_row6_col1" class="data row6 col1" >1.5909</td>
#       <td id="T_d14ea_row6_col2" class="data row6 col2" >0.5105</td>
#       <td id="T_d14ea_row6_col3" class="data row6 col3" >0.4956</td>
#       <td id="T_d14ea_row6_col4" class="data row6 col4" >0.0222</td>
#       <td id="T_d14ea_row6_col5" class="data row6 col5" >0.0208</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# </style>
# <table id="T_224b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_224b6_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_224b6_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_224b6_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_224b6_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_224b6_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_224b6_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_224b6_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_224b6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_224b6_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_224b6_row0_col1" class="data row0 col1" >0.7134</td>
#       <td id="T_224b6_row0_col2" class="data row0 col2" >0.8383</td>
#       <td id="T_224b6_row0_col3" class="data row0 col3" >0.9156</td>
#       <td id="T_224b6_row0_col4" class="data row0 col4" >0.6165</td>
#       <td id="T_224b6_row0_col5" class="data row0 col5" >0.0499</td>
#       <td id="T_224b6_row0_col6" class="data row0 col6" >0.0397</td>
#     </tr>
#   </tbody>
# </table>

# %%
# 集成
models = ensemble(tune_models)
# Out:
# <style type="text/css">
# #T_69c0d_row5_col0, #T_69c0d_row5_col1, #T_69c0d_row5_col2, #T_69c0d_row5_col3, #T_69c0d_row5_col4, #T_69c0d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_69c0d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_69c0d_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_69c0d_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_69c0d_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_69c0d_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_69c0d_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_69c0d_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69c0d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_
# [LightGBM] [Warning] bagging_freq is set=2, subsample_freq=0 will be ignored. Current value: bagging_freq=2
# <style type="text/css">
# #T_6004b th {
#   text-align: left;
# }
# #T_6004b_row0_col0, #T_6004b_row1_col0, #T_6004b_row1_col1, #T_6004b_row1_col2, #T_6004b_row1_col3, #T_6004b_row1_col4, #T_6004b_row1_col5, #T_6004b_row1_col6, #T_6004b_row2_col0, #T_6004b_row2_col1, #T_6004b_row2_col2, #T_6004b_row2_col3, #T_6004b_row2_col4, #T_6004b_row2_col5, #T_6004b_row2_col6, #T_6004b_row3_col0, #T_6004b_row3_col1, #T_6004b_row3_col2, #T_6004b_row3_col3, #T_6004b_row3_col4, #T_6004b_row3_col5, #T_6004b_row3_col6, #T_6004b_row4_col0, #T_6004b_row4_col1, #T_6004b_row4_col2, #T_6004b_row4_col3, #T_6004b_row4_col4, #T_6004b_row4_col5, #T_6004b_row4_col6, #T_6004b_row5_col0, #T_6004b_row5_col1, #T_6004b_row5_col2, #T_6004b_row5_col3, #T_6004b_row5_col4, #T_6004b_row5_col5, #T_6004b_row5_col6, #T_6004b_row6_col0, #T_6004b_row6_col1, #T_6004b_row6_col2, #T_6004b_row6_col3, #T_6004b_row6_col4, #T_6004b_row6_col5, #T_6004b_row6_col6 {
#   text-align: left;
# }
# #T_6004b_row0_col1, #T_6004b_row0_col2, #T_6004b_row0_col3, #T_6004b_row0_col4, #T_6004b_row0_col5, #T_6004b_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6004b_row0_col7, #T_6004b_row1_col7, #T_6004b_row2_col7, #T_6004b_row3_col7, #T_6004b_row4_col7, #T_6004b_row6_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6004b_row5_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6004b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6004b_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6004b_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_6004b_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_6004b_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_6004b_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_6004b_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_6004b_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_6004b_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6004b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6004b_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_6004b_row0_col1" class="data row0 col1" >0.9192</td>
#       <td id="T_6004b_row0_col2" class="data row0 col2" >1.4929</td>
#       <td id="T_6004b_row0_col3" class="data row0 col3" >1.1150</td>
#       <td id="T_6004b_row0_col4" class="data row0 col4" >0.5092</td>
#       <td id="T_6004b_row0_col5" class="data row0 col5" >0.0596</td>
#       <td id="T_6004b_row0_col6" class="data row0 col6" >0.0513</td>
#       <td id="T_6004b_row0_col7" class="data row0 col7" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row1" class="row_heading level0 row1" >6</th>
#       <td id="T_6004b_row1_col0" class="data row1 col0" >Voting Regressor</td>
#       <td id="T_6004b_row1_col1" class="data row1 col1" >0.9678</td>
#       <td id="T_6004b_row1_col2" class="data row1 col2" >1.6189</td>
#       <td id="T_6004b_row1_col3" class="data row1 col3" >1.1789</td>
#       <td id="T_6004b_row1_col4" class="data row1 col4" >0.4153</td>
#       <td id="T_6004b_row1_col5" class="data row1 col5" >0.0640</td>
#       <td id="T_6004b_row1_col6" class="data row1 col6" >0.0546</td>
#       <td id="T_6004b_row1_col7" class="data row1 col7" >0.1820</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row2" class="row_heading level0 row2" >1</th>
#       <td id="T_6004b_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6004b_row2_col1" class="data row2 col1" >0.9589</td>
#       <td id="T_6004b_row2_col2" class="data row2 col2" >1.6766</td>
#       <td id="T_6004b_row2_col3" class="data row2 col3" >1.1829</td>
#       <td id="T_6004b_row2_col4" class="data row2 col4" >0.4088</td>
#       <td id="T_6004b_row2_col5" class="data row2 col5" >0.0642</td>
#       <td id="T_6004b_row2_col6" class="data row2 col6" >0.0539</td>
#       <td id="T_6004b_row2_col7" class="data row2 col7" >0.0280</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6004b_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_6004b_row3_col1" class="data row3 col1" >0.9746</td>
#       <td id="T_6004b_row3_col2" class="data row3 col2" >1.6202</td>
#       <td id="T_6004b_row3_col3" class="data row3 col3" >1.1995</td>
#       <td id="T_6004b_row3_col4" class="data row3 col4" >0.3871</td>
#       <td id="T_6004b_row3_col5" class="data row3 col5" >0.0655</td>
#       <td id="T_6004b_row3_col6" class="data row3 col6" >0.0557</td>
#       <td id="T_6004b_row3_col7" class="data row3 col7" >0.0540</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_6004b_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_6004b_row4_col1" class="data row4 col1" >1.0380</td>
#       <td id="T_6004b_row4_col2" class="data row4 col2" >1.8538</td>
#       <td id="T_6004b_row4_col3" class="data row4 col3" >1.2622</td>
#       <td id="T_6004b_row4_col4" class="data row4 col4" >0.3571</td>
#       <td id="T_6004b_row4_col5" class="data row4 col5" >0.0685</td>
#       <td id="T_6004b_row4_col6" class="data row4 col6" >0.0584</td>
#       <td id="T_6004b_row4_col7" class="data row4 col7" >0.0360</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row5" class="row_heading level0 row5" >4</th>
#       <td id="T_6004b_row5_col0" class="data row5 col0" >Extreme Gradient Boosting</td>
#       <td id="T_6004b_row5_col1" class="data row5 col1" >1.0065</td>
#       <td id="T_6004b_row5_col2" class="data row5 col2" >1.7147</td>
#       <td id="T_6004b_row5_col3" class="data row5 col3" >1.2225</td>
#       <td id="T_6004b_row5_col4" class="data row5 col4" >0.3349</td>
#       <td id="T_6004b_row5_col5" class="data row5 col5" >0.0671</td>
#       <td id="T_6004b_row5_col6" class="data row5 col6" >0.0573</td>
#       <td id="T_6004b_row5_col7" class="data row5 col7" >0.0260</td>
#     </tr>
#     <tr>
#       <th id="T_6004b_level0_row6" class="row_heading level0 row6" >2</th>
#       <td id="T_6004b_row6_col0" class="data row6 col0" >Extra Trees Regressor</td>
#       <td id="T_6004b_row6_col1" class="data row6 col1" >1.0179</td>
#       <td id="T_6004b_row6_col2" class="data row6 col2" >1.7662</td>
#       <td id="T_6004b_row6_col3" class="data row6 col3" >1.2488</td>
#       <td id="T_6004b_row6_col4" class="data row6 col4" >0.3164</td>
#       <td id="T_6004b_row6_col5" class="data row6 col5" >0.0682</td>
#       <td id="T_6004b_row6_col6" class="data row6 col6" >0.0575</td>
#       <td id="T_6004b_row6_col7" class="data row6 col7" >0.0400</td>
#     </tr>
#   </tbody>
# </table>

# %%
for model_name, model in models.items():
    print(f"\n{'-'*30}")
    print(f"正在分析模型: {model_name.upper()}")
    print(f"{'-'*30}")
    
    # SHAP值解释（需要安装shap包）
    try:
        interpret_model(model)
        plot_model(model, plot = 'feature')
    except:
        print(f"{model_name} 不支持SHAP分析")
# Out:
# ------------------------------
# 正在分析模型: CATBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: LIGHTGBM
# ------------------------------
# ------------------------------
# 正在分析模型: ET
# ------------------------------
# ------------------------------
# 正在分析模型: RF
# ------------------------------
# ------------------------------
# 正在分析模型: XGBOOST
# ------------------------------
# ------------------------------
# 正在分析模型: GBR
# ------------------------------
# gbr 不支持SHAP分析
#
# ------------------------------
# 正在分析模型: BLEND
# ------------------------------
# blend 不支持SHAP分析

# %%
# 定义需要包含的模型简称集合
include_models = {'catboost','gbr','xgboost'}

# 生成过滤后的有序字典
seleced_model_dict = {
    k: v for k, v in tune_models.items()
    if k in include_models
}
# 集成
seleced_models = ensemble(seleced_model_dict)
# Out:
# <style type="text/css">
# #T_8d99d_row5_col0, #T_8d99d_row5_col1, #T_8d99d_row5_col2, #T_8d99d_row5_col3, #T_8d99d_row5_col4, #T_8d99d_row5_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_8